# %%
from langgraph.store.memory import InMemoryStore

# %%
store =InMemoryStore()

# %%
namespace = ("user","u1")

# %%
store.put(namespace=namespace,key="1",value={"data":"User like pizza"})
store.put(namespace=namespace,key="2",value={"data":"User prefer dark mod"})

# %%
store.put(namespace=namespace,key="1",value={"data":"User like pizza2"})

# %%
store.get(namespace=namespace,key="1")
# Out:
# Item(namespace=['user', 'u1'], key='1', value={'data': 'User like pizza2'}, created_at='2026-07-30T12:00:15.234965+00:00', updated_at='2026-07-30T12:00:15.234970+00:00')

# %% [markdown]
# # Retreiving all memory

# %%
store.search(namespace)
# Out:
# [Item(namespace=['user', 'u1'], key='1', value={'data': 'User like pizza2'}, created_at='2026-07-30T12:00:15.234965+00:00', updated_at='2026-07-30T12:00:15.234970+00:00', score=None),
#  Item(namespace=['user', 'u1'], key='2', value={'data': 'User prefer dark mod'}, created_at='2026-07-30T11:59:56.368633+00:00', updated_at='2026-07-30T11:59:56.368636+00:00', score=None)]
