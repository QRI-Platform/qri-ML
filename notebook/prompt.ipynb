# %%
# !pip install dotenv langchain langfuse
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.5/571.5 kB 427.1 kB/s eta 0:00:001m415.1 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.9/753.9 kB 520.1 kB/s eta 0:00:00 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 794.2/794.2 kB 254.2 kB/s eta 0:00:001m786.7 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.9/789.9 kB 592.2 kB/s eta 0:00:001m497.8 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 329.8 kB/s eta 0:00:001m319.1 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40/40 [langchain] 38/40 [langgraph]sdk]]dk]antic-conventions]
# ...

# %%
from langfuse import Langfuse

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
lf = Langfuse()

# %%
chat=lf.get_prompt("CHAT_PROMPT")

# %%
chat.prompt
# Out:
# [{'type': 'message',
#   'role': 'system',
# ...

# %%
chat.get_langchain_prompt
# Out:
# <bound method ChatPromptClient.get_langchain_prompt of <langfuse.model.ChatPromptClient object at 0x7a920b019940>>

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
chat=ChatPromptTemplate.from_messages(chat.get_langchain_prompt())
# Out:
# Placeholders ['messages'] have not been resolved. Pass them as keyword arguments to compile().

# %%
chat.invoke({"user_memories":"aloo","context":"kaloo","max_words":9,"messages":"kaloo"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 chat.invoke({"user_memories":"aloo","context":"kaloo","max_words":9,"messages":"kaloo"})
#
# File ~/Projects/sih/isro/.venv/lib/python3.14/site-packages/langchain_core/prompts/base.py:230, in BasePromptTemplate.invoke(self, input, config, **kwargs)
#     228 if self.tags:
#     229     config["tags"] += self.tags
# --> 230 return self._call_with_config(
#     231     self._format_prompt_with_error_handling,
#     232     input,
#     233     config,
#     234     run_type="prompt",
#     235     serialized=self._serialized,
#     236 )
#
# File ~/Projects/sih/isro/.venv/lib/python3.14/site-packages/langchain_core/runnables/base.py:2301, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
# ...
